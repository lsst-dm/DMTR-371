# %% [markdown]
# ## Test notebook for Data Management Acceptance Test Campaign 1
# This test will be executed on the Rubin Science Platform Notebook Aspect at the Interim Data Facility, initialized with Science Pipelines release w_2022_40.
#
# ### Test case LVV-T2698: Verify implementation of Catalog Metadata Access
#
# Verify that available catalog data products' metadata can be listed and retrieved.

# %%
from lsst.daf.butler import Butler

import matplotlib.pyplot as plt
import numpy as np
import lsst.afw.display as afwDisplay

# %% [markdown]
# #### Initialize the butler pointing to DP0.2 data:

# %%
# For DP0.2 data on the IDF:                                                                                                           
config = 'dp02'
collection = '2.2i/runs/DP0.2'
butler = Butler(config, collections=collection)
# Out:
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">botocore.credentials</span> <span style="color: var(--jp-info-color0)">INFO</span>: Found credentials in shared credentials file: /home/jeffcarlin/.lsst/aws-credentials.ini</pre>

# %% [markdown]
# #### Define some data dimensions to use for querying datasets:

# %%
tract = 3828
patch = 42
detector = 42

# %% [markdown]
# #### Execute a butler registry query to list `src` catalogs that match the selected dimensions.
#
# Note that `src` catalogs (which are derived from `calexp` images) are defined with dimensions of visit and detector, but here we supply tract and patch constraints. This demonstrates that the query is able to identify which visits overlap the patch/tract combination that has been provided.

# %%
data_refs = butler.registry.queryDatasets(
    datasetType="src",
    where=f"tract={tract} and patch={patch} and detector={detector} and skymap='DC2'")

data_ids = []

for data_ref in data_refs:
    print(data_ref.dataId.full)
    data_ids.append(data_ref.dataId.full)
# Out:
# {band: 'r', instrument: 'LSSTCam-imSim', detector: 42, physical_filter: 'r_sim_1.4', visit_system: 1, visit: 414872}
# {band: 'i', instrument: 'LSSTCam-imSim', detector: 42, physical_filter: 'i_sim_1.4', visit_system: 1, visit: 457676}
# {band: 'i', instrument: 'LSSTCam-imSim', detector: 42, physical_filter: 'i_sim_1.4', visit_system: 1, visit: 713247}
# {band: 'i', instrument: 'LSSTCam-imSim', detector: 42, physical_filter: 'i_sim_1.4', visit_system: 1, visit: 1013706}
# {band: 'y', instrument: 'LSSTCam-imSim', detector: 42, physical_filter: 'y_sim_1.4', visit_system: 1, visit: 1138156}
# {band: 'r', instrument: 'LSSTCam-imSim', detector: 42, physical_filter: 'r_sim_1.4', visit_system: 1, visit: 1155522}
# {band: 'z', instrument: 'LSSTCam-imSim', detector: 42, physical_filter: 'z_sim_1.4', visit_system: 1, visit: 1174350}
# {band: 'r', instrument: 'LSSTCam-imSim', detector: 42, physical_filter: 'r_sim_1.4', visit_system: 1, visit: 1192139}

# %% [markdown]
# This demonstrates the ability to identify and list available catalog datasets via the Butler middleware.
#
# #### Select a dataref for a single "src" catalog whose metadata we wish to examine
#
# We will use two methods to retrieve metadata:
# 1. Using `queryDimensionRecords`
# 2. Using `butler.get` to directly return a metadata `PropertySet`

# %%
# Query dimension records takes a data dimension as its argument.
#   First, specify "patch" associated with the given calexp dataref.

calexp_patch_metadata = butler.registry.queryDimensionRecords('patch', dataId=data_ref.dataId.full)

# %%
# We will use the "limit" method to display only the first 3 query results:
calexp_patch_metadata.limit(3)

# %%
# Print each of the patch results:

for md in calexp_patch_metadata:
    print(md)
# Out:
# patch:
#   skymap: 'DC2'
#   tract: 4026
#   id: 0
#   cell_x: 0
#   cell_y: 0
#   region: ConvexPolygon([UnitVector3d(0.43026204775397675, 0.6883194991736487, -0.5840298257108897), UnitVector3d(0.426896946056187, 0.6904343352140867, -0.5840029333876526), UnitVector3d(0.42814659142302663, 0.6923830193472248, -0.5807721160424839), UnitVector3d(0.4315119065467899, 0.690268177119236, -0.5807988620553948)])
# patch:
#   skymap: 'DC2'
#   tract: 3828
#   id: 14
#   cell_x: 0
#   cell_y: 2
#   region: ConvexPolygon([UnitVector3d(0.43225411615451825, 0.674246956004566, -0.5987882942961168), UnitVector3d(0.4289137602433692, 0.6764012038060476, -0.5987607182870492), UnitVector3d(0.4302504356192291, 0.6784326031288027, -0.5954945555261946), UnitVector3d(0.43359090615381846, 0.6762784153600475, -0.595521981977839)])
# patch:
#   skymap: 'DC2'
#   tract: 3828
#   id: 21
#   cell_x: 0
#   cell_y: 3
#   region: ConvexPolygon([UnitVector3d(0.4335274115486272, 0.6761819320093019, -0.5956777469908667), UnitVector3d(0.4301869452014568, 0.6783361234234796, -0.5956503133861719), UnitVector3d(0.4315168467136693, 0.6803568403259412, -0.5923746963063102), UnitVector3d(0.4348573743048953, 0.6782027419832244, -0.5924019790472412)])

# %%
calexp_visit_metadata = butler.registry.queryDimensionRecords('visit', dataId=data_ref.dataId.full)

# Print each of the visit results:

for md in calexp_visit_metadata:
    print(md)
# Out:
# visit:
#   instrument: 'LSSTCam-imSim'
#   id: 1192139
#   physical_filter: 'r_sim_1.4'
#   visit_system: 1
#   name: '1192139'
#   day_obs: 20261013
#   exposure_time: 30.0
#   target_name: 'UNKNOWN'
#   observation_reason: 'imsim'
#   science_program: '1192139'
#   zenith_angle: 33.24096737781019
#   region: ConvexPolygon([UnitVector3d(0.4540277748455429, 0.6654318675118485, -0.5925024973521197), UnitVector3d(0.44361089583980434, 0.6666796471459634, -0.598955441726294), UnitVector3d(0.44013053225756876, 0.6670744011796488, -0.6010797433498173), UnitVector3d(0.4260404067595378, 0.6772198775092578, -0.5998856635347384), UnitVector3d(0.42474273135972046, 0.6804005906510217, -0.5972006768238172), UnitVector3d(0.42352041810442, 0.6833765117193251, -0.5946654510554521), UnitVector3d(0.416036425154166, 0.7010293564947697, -0.5791990454735497), UnitVector3d(0.41477118744011865, 0.7039234874245276, -0.5765904837244583), UnitVector3d(0.4214115188412533, 0.7114581756650987, -0.5623518436594634), UnitVector3d(0.425169183247371, 0.7110437231908872, -0.5600428459748454), UnitVector3d(0.42864039934343073, 0.7106424941030932, -0.5579020107739703), UnitVector3d(0.4321022500797612, 0.7102295896872688, -0.5557531605026296), UnitVector3d(0.4527659293386402, 0.7074880385949052, -0.54264508518483), UnitVector3d(0.4668616187641439, 0.6973281169728714, -0.5438508308387443), UnitVector3d(0.46822296389633905, 0.6942454178035495, -0.546617376177251), UnitVector3d(0.47200158939527126, 0.6854751220272934, -0.5543810572972394), UnitVector3d(0.47324331744303, 0.6825308145151987, -0.5569492344305135), UnitVector3d(0.4769213668942926, 0.6736166079988362, -0.5646119687252669), UnitVector3d(0.4781283304168948, 0.6706298531636404, -0.5671409874964662), UnitVector3d(0.47149361115917676, 0.6631017370072779, -0.5813689542915151), UnitVector3d(0.4678006327075857, 0.6636157674371148, -0.5837608082487481), UnitVector3d(0.4643763329318669, 0.6640830601476755, -0.5859593080049592)])
#   timespan: Timespan(begin=astropy.time.Time('2026-10-14 04:22:46.411200', scale='tai', format='iso'), end=astropy.time.Time('2026-10-14 04:23:16.411000', scale='tai', format='iso'))

# %%
calexp_detector_metadata = butler.registry.queryDimensionRecords('detector', dataId=data_ref.dataId.full)

# Print each of the visit results:

for md in calexp_detector_metadata:
    print(md)
# Out:
# detector:
#   instrument: 'LSSTCam-imSim'
#   id: 42
#   full_name: 'R11_S20'
#   name_in_raft: 'S20'
#   raft: 'R11'
#   purpose: 'SCIENCE'

# %% [markdown]
# We have demonstrated that metadata associated with a given dataref can be retrieved using the `queryDimensionRecords` method.
#
# #### Find and retrieve metadata directly with butler.get():
#
# First, query the dataset types in the butler to identify those with "metadata" in their name. We will further limit the results to those with a storage class of `PropertySet`.

# %%
md_dataset_types = []

for ds in butler.registry.queryDatasetTypes():
    if "metadata" in ds.name and ds.storageClass_name == 'PropertySet':
        # print(ds)
        md_dataset_types.append(ds)

print('Returned ', len(md_dataset_types), ' dataset types with metadata in them.')
# Out:
# Returned  156  dataset types with metadata in them.

# %%
# Because the query returned a lot of results, print just the first 3 to the screen:

md_dataset_types[0:13]
# Out:
# [DatasetType('isr_metadata', {band, instrument, detector, physical_filter, exposure}, PropertySet),
#  DatasetType('characterizeImage_metadata', {band, instrument, detector, physical_filter, visit_system, visit}, PropertySet),
#  DatasetType('calibrate_metadata', {band, instrument, detector, physical_filter, visit_system, visit}, PropertySet),
#  DatasetType('consolidateVisitSummary_metadata', {band, instrument, physical_filter, visit_system, visit}, PropertySet),
#  DatasetType('makeWarp_metadata', {band, instrument, skymap, physical_filter, tract, visit_system, patch, visit}, PropertySet),
#  DatasetType('measure_metadata', {band, skymap, tract, patch}, PropertySet),
#  DatasetType('mergeDetections_metadata', {skymap, tract, patch}, PropertySet),
#  DatasetType('forcedPhotCcd_metadata', {band, instrument, skymap, detector, physical_filter, tract, visit_system, visit}, PropertySet),
#  DatasetType('assembleCoadd_metadata', {band, skymap, tract, patch}, PropertySet),
#  DatasetType('detection_metadata', {band, skymap, tract, patch}, PropertySet),
#  DatasetType('forcedPhotCoadd_metadata', {band, skymap, tract, patch}, PropertySet),
#  DatasetType('deblend_metadata', {skymap, tract, patch}, PropertySet),
#  DatasetType('mergeMeasurements_metadata', {skymap, tract, patch}, PropertySet)]

# %% [markdown]
# #### Select `calibrate_metadata`, retrieve it, and examine its contents:

# %%
calibrate_metadata = butler.get('calibrate_metadata', dataId = data_ref.dataId.full)

# %%
for v in calibrate_metadata.values():
    print(v)
# Out:
# runStartUtc = "2022-01-03T14:27:01.303472"
# runStartCpuTime = 10576.362046784
# runStartUserTime = 10193.241786000
# runStartSystemTime = 383.12026400000
# runStartMaxResidentSetSize = 3084460
# runStartMinorPageFaults = 99609347
# runStartMajorPageFaults = 8
# runStartBlockInputs = 63528
# runStartBlockOutputs = 78739800
# runStartVoluntaryContextSwitches = 2237238
# runStartInvoluntaryContextSwitches = 8650111
# runEndUtc = "2022-01-03T14:27:30.092458"
# runEndCpuTime = 10605.141212355
# runEndUserTime = 10221.962621000
# runEndSystemTime = 383.17862400000
# runEndMaxResidentSetSize = 3084460
# runEndMinorPageFaults = 99633447
# runEndMajorPageFaults = 8
# runEndBlockInputs = 63528
# runEndBlockOutputs = 78739800
# runEndVoluntaryContextSwitches = 2237238
# runEndInvoluntaryContextSwitches = 8650225
#
# runStartUtc = "2022-01-03T14:26:57.066075"
# runStartCpuTime = 10572.125674412
# runStartUserTime = 10189.319344000
# runStartSystemTime = 382.80636000000
# runStartMaxResidentSetSize = 3084460
# runStartMinorPageFaults = 99440958
# runStartMajorPageFaults = 8
# runStartBlockInputs = 63528
# runStartBlockOutputs = 78739784
# runStartVoluntaryContextSwitches = 2237238
# runStartInvoluntaryContextSwitches = 8650101
# runEndUtc = "2022-01-03T14:27:32.755855"
# runEndCpuTime = 10608.089961008
# runEndUserTime = 10224.451470000
# runEndSystemTime = 383.63850900000
# runEndMaxResidentSetSize = 3084460
# runEndMinorPageFaults = 99681667
# runEndMajorPageFaults = 8
# runEndBlockInputs = 63528
# runEndBlockOutputs = 78765720
# runEndVoluntaryContextSwitches = 2237974
# runEndInvoluntaryContextSwitches = 8650400
#
# runStartUtc = "2022-01-03T14:27:30.351036"
# runStartCpuTime = 10605.399765830
# runStartUserTime = 10222.221138000
# runStartSystemTime = 383.17865000000
# runStartMaxResidentSetSize = 3084460
# runStartMinorPageFaults = 99633447
# runStartMajorPageFaults = 8
# runStartBlockInputs = 63528
# runStartBlockOutputs = 78739816
# runStartVoluntaryContextSwitches = 2237238
# runStartInvoluntaryContextSwitches = 8650225
# runEndUtc = "2022-01-03T14:27:30.412640"
# runEndCpuTime = 10605.461363071
# runEndUserTime = 10222.282738000
# runEndSystemTime = 383.17865000000
# runEndMaxResidentSetSize = 3084460
# runEndMinorPageFaults = 99633447
# runEndMajorPageFaults = 8
# runEndBlockInputs = 63528
# runEndBlockOutputs = 78739816
# runEndVoluntaryContextSwitches = 2237238
# runEndInvoluntaryContextSwitches = 8650225
#
# runStartUtc = "2022-01-03T14:27:31.730922"
# runStartCpuTime = 10607.065157454
# runStartUserTime = 10223.522621000
# runStartSystemTime = 383.54254400000
# runStartMaxResidentSetSize = 3084460
# runStartMinorPageFaults = 99633467
# runStartMajorPageFaults = 8
# runStartBlockInputs = 63528
# runStartBlockOutputs = 78765712
# runStartVoluntaryContextSwitches = 2237974
# runStartInvoluntaryContextSwitches = 8650397
# runEndUtc = "2022-01-03T14:27:32.752343"
# runEndCpuTime = 10608.086449423
# runEndUserTime = 10224.447993000
# runEndSystemTime = 383.63847600000
# runEndMaxResidentSetSize = 3084460
# runEndMinorPageFaults = 99681667
# runEndMajorPageFaults = 8
# runEndBlockInputs = 63528
# runEndBlockOutputs = 78765720
# runEndVoluntaryContextSwitches = 2237974
# runEndInvoluntaryContextSwitches = 8650400
#
#
#
# prepUtc = "2022-01-03T14:26:55.488602"
# prepCpuTime = 10570.958865802
# prepUserTime = 10188.214710000
# prepSystemTime = 382.74417000000
# prepMaxResidentSetSize = 3084460
# prepMinorPageFaults = 99425014
# prepMajorPageFaults = 8
# prepBlockInputs = 63416
# prepBlockOutputs = 78737384
# prepVoluntaryContextSwitches = 2237054
# prepInvoluntaryContextSwitches = 8650094
# initUtc = "2022-01-03T14:26:55.813563"
# initCpuTime = 10571.063924614
# initUserTime = 10188.317705000
# initSystemTime = 382.74623500000
# initMaxResidentSetSize = 3084460
# initMinorPageFaults = 99425014
# initMajorPageFaults = 8
# initBlockInputs = 63528
# initBlockOutputs = 78737384
# initVoluntaryContextSwitches = 2237080
# initInvoluntaryContextSwitches = 8650095
# startUtc = "2022-01-03T14:26:55.907885"
# startCpuTime = 10571.116052497
# startUserTime = 10188.368786000
# startSystemTime = 382.74728100000
# startMaxResidentSetSize = 3084460
# startMinorPageFaults = 99425021
# startMajorPageFaults = 8
# startBlockInputs = 63528
# startBlockOutputs = 78737712
# startVoluntaryContextSwitches = 2237097
# startInvoluntaryContextSwitches = 8650096
# endUtc = "2022-01-03T14:27:37.228652"
# endCpuTime = 10611.324140903
# endUserTime = 10227.313279000
# endSystemTime = 384.01088800000
# endMaxResidentSetSize = 3084460
# endMinorPageFaults = 99761227
# endMajorPageFaults = 8
# endBlockInputs = 63568
# endBlockOutputs = 78994432
# endVoluntaryContextSwitches = 2238350
# endInvoluntaryContextSwitches = 8650443
#
#
#
#
# runStartUtc = "2022-01-03T14:27:31.350257"
# runStartCpuTime = 10606.792002216
# runStartUserTime = 10223.266409000
# runStartSystemTime = 383.52559600000
# runStartMaxResidentSetSize = 3084460
# runStartMinorPageFaults = 99633457
# runStartMajorPageFaults = 8
# runStartBlockInputs = 63528
# runStartBlockOutputs = 78752768
# runStartVoluntaryContextSwitches = 2237940
# runStartInvoluntaryContextSwitches = 8650391
# extractMagArraysStartUtc = "2022-01-03T14:27:31.726209"
# extractMagArraysStartCpuTime = 10607.060444008
# extractMagArraysStartUserTime = 10223.517948000
# extractMagArraysStartSystemTime = 383.54250600000
# extractMagArraysStartMaxResidentSetSize = 3084460
# extractMagArraysStartMinorPageFaults = 99633467
# extractMagArraysStartMajorPageFaults = 8
# extractMagArraysStartBlockInputs = 63528
# extractMagArraysStartBlockOutputs = 78765712
# extractMagArraysStartVoluntaryContextSwitches = 2237974
# extractMagArraysStartInvoluntaryContextSwitches = 8650397
# extractMagArraysEndUtc = "2022-01-03T14:27:31.728042"
# extractMagArraysEndCpuTime = 10607.062276513
# extractMagArraysEndUserTime = 10223.519751000
# extractMagArraysEndSystemTime = 383.54253500000
# extractMagArraysEndMaxResidentSetSize = 3084460
# extractMagArraysEndMinorPageFaults = 99633467
# extractMagArraysEndMajorPageFaults = 8
# extractMagArraysEndBlockInputs = 63528
# extractMagArraysEndBlockOutputs = 78765712
# extractMagArraysEndVoluntaryContextSwitches = 2237974
# extractMagArraysEndInvoluntaryContextSwitches = 8650397
# runEndUtc = "2022-01-03T14:27:31.730165"
# runEndCpuTime = 10607.064401385
# runEndUserTime = 10223.521873000
# runEndSystemTime = 383.54253500000
# runEndMaxResidentSetSize = 3084460
# runEndMinorPageFaults = 99633467
# runEndMajorPageFaults = 8
# runEndBlockInputs = 63528
# runEndBlockOutputs = 78765712
# runEndVoluntaryContextSwitches = 2237974
# runEndInvoluntaryContextSwitches = 8650397
#
#
# runStartUtc = "2022-01-03T14:26:57.066712"
# runStartCpuTime = 10572.126324992
# runStartUserTime = 10189.319954000
# runStartSystemTime = 382.80638300000
# runStartMaxResidentSetSize = 3084460
# runStartMinorPageFaults = 99440958
# runStartMajorPageFaults = 8
# runStartBlockInputs = 63528
# runStartBlockOutputs = 78739784
# runStartVoluntaryContextSwitches = 2237238
# runStartInvoluntaryContextSwitches = 8650101
# detectFootprintsStartUtc = "2022-01-03T14:26:57.066886"
# detectFootprintsStartCpuTime = 10572.126501223
# detectFootprintsStartUserTime = 10189.320118000
# detectFootprintsStartSystemTime = 382.80638900000
# detectFootprintsStartMaxResidentSetSize = 3084460
# detectFootprintsStartMinorPageFaults = 99440958
# detectFootprintsStartMajorPageFaults = 8
# detectFootprintsStartBlockInputs = 63528
# detectFootprintsStartBlockOutputs = 78739784
# detectFootprintsStartVoluntaryContextSwitches = 2237238
# detectFootprintsStartInvoluntaryContextSwitches = 8650101
# doSmooth = 1
# sigma = 1.8501396386975
# smoothingKernelWidth = 13
# nGrow = 4
# detectFootprintsEndUtc = "2022-01-03T14:26:59.745312"
# detectFootprintsEndCpuTime = 10574.804609222
# detectFootprintsEndUserTime = 10191.722352000
# detectFootprintsEndSystemTime = 383.08228200000
# detectFootprintsEndMaxResidentSetSize = 3084460
# detectFootprintsEndMinorPageFaults = 99585273
# detectFootprintsEndMajorPageFaults = 8
# detectFootprintsEndBlockInputs = 63528
# detectFootprintsEndBlockOutputs = 78739792
# detectFootprintsEndVoluntaryContextSwitches = 2237238
# detectFootprintsEndInvoluntaryContextSwitches = 8650107
# runEndUtc = "2022-01-03T14:26:59.748269"
# runEndCpuTime = 10574.807567974
# runEndUserTime = 10191.725304000
# runEndSystemTime = 383.08228200000
# runEndMaxResidentSetSize = 3084460
# runEndMinorPageFaults = 99585273
# runEndMajorPageFaults = 8
# runEndBlockInputs = 63528
# runEndBlockOutputs = 78739792
# runEndVoluntaryContextSwitches = 2237238
# runEndInvoluntaryContextSwitches = 8650107
#
# runStartUtc = "2022-01-03T14:26:59.820551"
# runStartCpuTime = 10574.879843951
# runStartUserTime = 10191.797573000
# runStartSystemTime = 383.08228200000
# runStartMaxResidentSetSize = 3084460
# runStartMinorPageFaults = 99585273
# runStartMajorPageFaults = 8
# runStartBlockInputs = 63528
# runStartBlockOutputs = 78739792
# runStartVoluntaryContextSwitches = 2237238
# runStartInvoluntaryContextSwitches = 8650107
# deblendStartUtc = "2022-01-03T14:26:59.820750"
# deblendStartCpuTime = 10574.880045631
# deblendStartUserTime = 10191.797768000
# deblendStartSystemTime = 383.08228200000
# deblendStartMaxResidentSetSize = 3084460
# deblendStartMinorPageFaults = 99585273
# deblendStartMajorPageFaults = 8
# deblendStartBlockInputs = 63528
# deblendStartBlockOutputs = 78739792
# deblendStartVoluntaryContextSwitches = 2237238
# deblendStartInvoluntaryContextSwitches = 8650107
# deblendEndUtc = "2022-01-03T14:27:01.303224"
# deblendEndCpuTime = 10576.361796040
# deblendEndUserTime = 10193.241551000
# deblendEndSystemTime = 383.12025500000
# deblendEndMaxResidentSetSize = 3084460
# deblendEndMinorPageFaults = 99609347
# deblendEndMajorPageFaults = 8
# deblendEndBlockInputs = 63528
# deblendEndBlockOutputs = 78739800
# deblendEndVoluntaryContextSwitches = 2237238
# deblendEndInvoluntaryContextSwitches = 8650111
# runEndUtc = "2022-01-03T14:27:01.303385"
# runEndCpuTime = 10576.361959777
# runEndUserTime = 10193.241703000
# runEndSystemTime = 383.12026100000
# runEndMaxResidentSetSize = 3084460
# runEndMinorPageFaults = 99609347
# runEndMajorPageFaults = 8
# runEndBlockInputs = 63528
# runEndBlockOutputs = 78739800
# runEndVoluntaryContextSwitches = 2237238
# runEndInvoluntaryContextSwitches = 8650111
#
#
#
# runStartUtc = "2022-01-03T14:27:30.430474"
# runStartCpuTime = 10605.479197242
# runStartUserTime = 10222.300562000
# runStartSystemTime = 383.17865000000
# runStartMaxResidentSetSize = 3084460
# runStartMinorPageFaults = 99633447
# runStartMajorPageFaults = 8
# runStartBlockInputs = 63528
# runStartBlockOutputs = 78739816
# runStartVoluntaryContextSwitches = 2237238
# runStartInvoluntaryContextSwitches = 8650225
# solveStartUtc = "2022-01-03T14:27:30.430666"
# solveStartCpuTime = 10605.479391758
# solveStartUserTime = 10222.300750000
# solveStartSystemTime = 383.17865000000
# solveStartMaxResidentSetSize = 3084460
# solveStartMinorPageFaults = 99633447
# solveStartMajorPageFaults = 8
# solveStartBlockInputs = 63528
# solveStartBlockOutputs = 78739816
# solveStartVoluntaryContextSwitches = 2237238
# solveStartInvoluntaryContextSwitches = 8650225
# _matchAndFitWcsStartUtc = [ "2022-01-03T14:27:30.899218", "2022-01-03T14:27:31.065297", "2022-01-03T14:27:31.206793" ]
# _matchAndFitWcsStartCpuTime = [ 10605.734264952, 10606.104121652, 10606.445232800 ]
# _matchAndFitWcsStartUserTime = [ 10222.535517000, 10222.801400000, 10223.033609000 ]
# _matchAndFitWcsStartSystemTime = [ 383.19876000000, 383.30272600000, 383.41162900000 ]
# _matchAndFitWcsStartMaxResidentSetSize = [ 3084460, 3084460, 3084460 ]
# _matchAndFitWcsStartMinorPageFaults = [ 99633457, 99633457, 99633457 ]
# _matchAndFitWcsStartMajorPageFaults = [ 8, 8, 8 ]
# _matchAndFitWcsStartBlockInputs = [ 63528, 63528, 63528 ]
# _matchAndFitWcsStartBlockOutputs = [ 78752752, 78752760, 78752760 ]
# _matchAndFitWcsStartVoluntaryContextSwitches = [ 2237934, 2237936, 2237938 ]
# _matchAndFitWcsStartInvoluntaryContextSwitches = [ 8650228, 8650272, 8650356 ]
# _matchAndFitWcsEndUtc = [ "2022-01-03T14:27:31.065091", "2022-01-03T14:27:31.206548", "2022-01-03T14:27:31.348465" ]
# _matchAndFitWcsEndCpuTime = [ 10606.103915708, 10606.444988052, 10606.790209256 ]
# _matchAndFitWcsEndUserTime = [ 10222.801197000, 10223.033372000, 10223.264636000 ]
# _matchAndFitWcsEndSystemTime = [ 383.30272600000, 383.41162000000, 383.52557800000 ]
# _matchAndFitWcsEndMaxResidentSetSize = [ 3084460, 3084460, 3084460 ]
# _matchAndFitWcsEndMinorPageFaults = [ 99633457, 99633457, 99633457 ]
# _matchAndFitWcsEndMajorPageFaults = [ 8, 8, 8 ]
# _matchAndFitWcsEndBlockInputs = [ 63528, 63528, 63528 ]
# _matchAndFitWcsEndBlockOutputs = [ 78752760, 78752760, 78752768 ]
# _matchAndFitWcsEndVoluntaryContextSwitches = [ 2237936, 2237938, 2237940 ]
# _matchAndFitWcsEndInvoluntaryContextSwitches = [ 8650272, 8650356, 8650391 ]
# solveEndUtc = "2022-01-03T14:27:31.350026"
# solveEndCpuTime = 10606.791767172
# solveEndUserTime = 10223.266181000
# solveEndSystemTime = 383.52559600000
# solveEndMaxResidentSetSize = 3084460
# solveEndMinorPageFaults = 99633457
# solveEndMajorPageFaults = 8
# solveEndBlockInputs = 63528
# solveEndBlockOutputs = 78752768
# solveEndVoluntaryContextSwitches = 2237940
# solveEndInvoluntaryContextSwitches = 8650391
# runEndUtc = "2022-01-03T14:27:31.350165"
# runEndCpuTime = 10606.791909370
# runEndUserTime = 10223.266317000
# runEndSystemTime = 383.52559600000
# runEndMaxResidentSetSize = 3084460
# runEndMinorPageFaults = 99633457
# runEndMajorPageFaults = 8
# runEndBlockInputs = 63528
# runEndBlockOutputs = 78752768
# runEndVoluntaryContextSwitches = 2237940
# runEndInvoluntaryContextSwitches = 8650391
#
#
# matchObjectsToSourcesStartUtc = [ "2022-01-03T14:27:30.899357", "2022-01-03T14:27:31.065397", "2022-01-03T14:27:31.206885" ]
# matchObjectsToSourcesStartCpuTime = [ 10605.734407084, 10606.104222070, 10606.445326422 ]
# matchObjectsToSourcesStartUserTime = [ 10222.535646000, 10222.801499000, 10223.033697000 ]
# matchObjectsToSourcesStartSystemTime = [ 383.19876400000, 383.30272600000, 383.41163200000 ]
# matchObjectsToSourcesStartMaxResidentSetSize = [ 3084460, 3084460, 3084460 ]
# matchObjectsToSourcesStartMinorPageFaults = [ 99633457, 99633457, 99633457 ]
# matchObjectsToSourcesStartMajorPageFaults = [ 8, 8, 8 ]
# matchObjectsToSourcesStartBlockInputs = [ 63528, 63528, 63528 ]
# matchObjectsToSourcesStartBlockOutputs = [ 78752752, 78752760, 78752760 ]
# matchObjectsToSourcesStartVoluntaryContextSwitches = [ 2237934, 2237936, 2237938 ]
# matchObjectsToSourcesStartInvoluntaryContextSwitches = [ 8650228, 8650272, 8650356 ]
# _doMatchStartUtc = [ "2022-01-03T14:27:30.899467", "2022-01-03T14:27:31.065492", "2022-01-03T14:27:31.206980" ]
# _doMatchStartCpuTime = [ 10605.734517263, 10606.104317240, 10606.445420939 ]
# _doMatchStartUserTime = [ 10222.535752000, 10222.801591000, 10223.033788000 ]
# _doMatchStartSystemTime = [ 383.19876800000, 383.30272900000, 383.41163500000 ]
# _doMatchStartMaxResidentSetSize = [ 3084460, 3084460, 3084460 ]
# _doMatchStartMinorPageFaults = [ 99633457, 99633457, 99633457 ]
# _doMatchStartMajorPageFaults = [ 8, 8, 8 ]
# _doMatchStartBlockInputs = [ 63528, 63528, 63528 ]
# _doMatchStartBlockOutputs = [ 78752752, 78752760, 78752760 ]
# _doMatchStartVoluntaryContextSwitches = [ 2237934, 2237936, 2237938 ]
# _doMatchStartInvoluntaryContextSwitches = [ 8650228, 8650272, 8650356 ]
# _doMatchEndUtc = [ "2022-01-03T14:27:30.948174", "2022-01-03T14:27:31.091233", "2022-01-03T14:27:31.232411" ]
# _doMatchEndCpuTime = [ 10605.812866827, 10606.157249273, 10606.501070913 ]
# _doMatchEndUserTime = [ 10222.603181000, 10222.842614000, 10223.078529000 ]
# _doMatchEndSystemTime = [ 383.20975600000, 383.31470700000, 383.42261700000 ]
# _doMatchEndMaxResidentSetSize = [ 3084460, 3084460, 3084460 ]
# _doMatchEndMinorPageFaults = [ 99633457, 99633457, 99633457 ]
# _doMatchEndMajorPageFaults = [ 8, 8, 8 ]
# _doMatchEndBlockInputs = [ 63528, 63528, 63528 ]
# _doMatchEndBlockOutputs = [ 78752752, 78752760, 78752760 ]
# _doMatchEndVoluntaryContextSwitches = [ 2237934, 2237936, 2237938 ]
# _doMatchEndInvoluntaryContextSwitches = [ 8650240, 8650311, 8650358 ]
# matchObjectsToSourcesEndUtc = [ "2022-01-03T14:27:30.949389", "2022-01-03T14:27:31.092510", "2022-01-03T14:27:31.233692" ]
# matchObjectsToSourcesEndCpuTime = [ 10605.816158250, 10606.160720479, 10606.504561286 ]
# matchObjectsToSourcesEndUserTime = [ 10222.604436000, 10222.844020000, 10223.081911000 ]
# matchObjectsToSourcesEndSystemTime = [ 383.21175900000, 383.31673500000, 383.42268500000 ]
# matchObjectsToSourcesEndMaxResidentSetSize = [ 3084460, 3084460, 3084460 ]
# matchObjectsToSourcesEndMinorPageFaults = [ 99633457, 99633457, 99633457 ]
# matchObjectsToSourcesEndMajorPageFaults = [ 8, 8, 8 ]
# matchObjectsToSourcesEndBlockInputs = [ 63528, 63528, 63528 ]
# matchObjectsToSourcesEndBlockOutputs = [ 78752760, 78752760, 78752768 ]
# matchObjectsToSourcesEndVoluntaryContextSwitches = [ 2237934, 2237936, 2237938 ]
# matchObjectsToSourcesEndInvoluntaryContextSwitches = [ 8650246, 8650316, 8650363 ]
#
# fitWcsStartUtc = [ "2022-01-03T14:27:30.971763", "2022-01-03T14:27:31.115192", "2022-01-03T14:27:31.256290" ]
# fitWcsStartCpuTime = [ 10605.882480928, 10606.227856524, 10606.571271975 ]
# fitWcsStartUserTime = [ 10222.644762000, 10222.885256000, 10223.123694000 ]
# fitWcsStartSystemTime = [ 383.23775700000, 383.34264900000, 383.44762200000 ]
# fitWcsStartMaxResidentSetSize = [ 3084460, 3084460, 3084460 ]
# fitWcsStartMinorPageFaults = [ 99633457, 99633457, 99633457 ]
# fitWcsStartMajorPageFaults = [ 8, 8, 8 ]
# fitWcsStartBlockInputs = [ 63528, 63528, 63528 ]
# fitWcsStartBlockOutputs = [ 78752760, 78752760, 78752768 ]
# fitWcsStartVoluntaryContextSwitches = [ 2237934, 2237936, 2237938 ]
# fitWcsStartInvoluntaryContextSwitches = [ 8650265, 8650335, 8650377 ]
# fitWcsEndUtc = [ "2022-01-03T14:27:31.064872", "2022-01-03T14:27:31.206360", "2022-01-03T14:27:31.348256" ]
# fitWcsEndCpuTime = [ 10606.103691983, 10606.444795622, 10606.789995630 ]
# fitWcsEndUserTime = [ 10222.800983000, 10223.033200000, 10223.264442000 ]
# fitWcsEndSystemTime = [ 383.30272600000, 383.41161300000, 383.52557000000 ]
# fitWcsEndMaxResidentSetSize = [ 3084460, 3084460, 3084460 ]
# fitWcsEndMinorPageFaults = [ 99633457, 99633457, 99633457 ]
# fitWcsEndMajorPageFaults = [ 8, 8, 8 ]
# fitWcsEndBlockInputs = [ 63528, 63528, 63528 ]
# fitWcsEndBlockOutputs = [ 78752760, 78752760, 78752768 ]
# fitWcsEndVoluntaryContextSwitches = [ 2237936, 2237938, 2237940 ]
# fitWcsEndInvoluntaryContextSwitches = [ 8650272, 8650356, 8650391 ]

# %% [markdown]
# This search returned a different type of metadata than the first query, consisting primarily of information about configuration of the `calibrate` tasks and when they were executed.
#
# We have now demonstrated two ways that metadata can be identified and retrieved.
